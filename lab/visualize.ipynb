# %%
# %load_ext autoreload
# %autoreload 2
import os
project_name = "panamera"
os.chdir(os.path.join(os.getcwd().split(project_name, 1)[0], project_name))

# %%
from main import Main
main = Main(True)
main.load()

# %%
main.analyze()
# Out:
# Price column:
# count         10040.000000
# mean       48088823.730179
# std        43508075.654089
# min         3500000.000000
# 25%        27000000.000000
# 50%        37000000.000000
# 75%        53000000.000000
# max      1678000000.000000
# Name: price, dtype: object
#
#
#  mu = 48088823.73 and sigma = 43505908.86
# Skewness: 9.84962080258795
# Kurtosis: 246.4523796949662
# outer range (low) of the distribution:
# [[-1.02489121]
#  [-1.02489121]
#  [-1.02489121]
#  [-1.02489121]
#  [-1.01109998]
#  [-0.99156241]
#  [-0.99041314]
#  [-0.97892045]
#  [-0.97662191]
#  [-0.97202483]]
#
# outer range (high) of the distribution:
# [[ 9.23808252]
#  [ 9.81271711]
#  [ 9.87018057]
#  [10.89303013]
#  [11.69751856]
#  [13.37545155]
#  [15.44413607]
#  [17.28296675]
#  [20.73077427]
#  [37.46413347]]
# Dropped rows with price <= 100000
#
# Scattering ceiling_height to price
# df2: Dropped rows not in span: 10 <= ceiling_height <= 0.5 m
#
# ...

# %%
analyzer.df['ceiling_height'].fillna('NaN')
# Out:
# 0        NassN
# 1        3.200
# 2        3.300
# 3        2.700
# 4        3.300
#          ...
# 10035    2.700
# 10036    2.800
# 10037    2.740
# 10038    NassN
# 10039    2.800
# Name: ceiling_height, Length: 10040, dtype: object

# %%
analyzer.visualizer.scatter(analyzer.df, 'ceiling_height')
# Out:
# Scattering ceiling_height to price

# %%
nn.describe_post_proc()
# Out:
#        room_count     floor  max_floor  general_area  build_year  \
# count   25559.000 25559.000  25559.000     25559.000   25559.000
# mean        2.226     4.903      8.361        67.731    1997.777
# std         1.020     3.739      4.841        44.098      20.355
# min         1.000     1.000      1.000         8.300    1931.000
# 25%         1.000     2.000      5.000        43.000    1978.000
# 50%         2.000     4.000      7.000        58.000    2007.000
# 75%         3.000     7.000     10.000        75.000    2017.000
# max        15.000    37.000    133.000       620.000    2023.000
#
#                price  images_count       lat      long  text_len  ...  \
# count      25559.000     25559.000 25559.000 25559.000 25559.000  ...
# mean    46026898.183        11.092    43.236    76.887   439.235  ...
# std     51154983.473         8.895     0.046     0.048   381.365  ...
# min      4500000.000         0.000    43.125    76.773     0.000  ...
# ...
